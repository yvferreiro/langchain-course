# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain_mcp_adapters.client import MultiServerMCPClient

client = MultiServerMCPClient(
    {
        "travel_server": {
                "transport": "streamable_http",
                "url": "https://mcp.kiwi.com"
            }
    }
)

tools = await client.get_tools()

# %%
from langchain.agents import create_agent
from langgraph.checkpoint.memory import InMemorySaver

agent = create_agent(
    "gpt-5-nano",
    tools=tools,
    checkpointer=InMemorySaver(),
    system_prompt="You are a travel agent. No follow up questions."
)

# %%
from langchain.messages import HumanMessage

config = {"configurable": {"thread_id": "1"}}

response = await agent.ainvoke(
    {"messages": [HumanMessage(content="Get me a direct flight from Copenhagen to Doha on December 21s")]},
    config
    )

# %%
from pprint import pprint

pprint(response)
# Out:
# {'messages': [HumanMessage(content='Get me a direct flight from Copenhagen to Doha on December 21s', additional_kwargs={}, response_metadata={}, id='f387a328-7b05-4828-a089-16935e219c2a'),
#               AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 607, 'prompt_tokens': 2812, 'total_tokens': 3419, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 512, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-EHCN916NC1wFZFeyPMb6F5w1E3Wia', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--01a03f44-65b6-77e0-8896-ad5379ceb5d1-0', tool_calls=[{'name': 'search-flight', 'args': {'flyFrom': 'Copenhagen', 'flyTo': 'Doha', 'departureDate': '21/12/2026', 'departureDateFlexDays': 0, 'returnDate': None, 'returnDateFlexDays': 0, 'adults': 1, 'children': 0, 'infants': 0, 'cabinClass': 'M', 'currency': 'EUR', 'locale': 'en', 'max_sector_stopovers': 0}, 'id': 'call_zA21lrCa6wJSkoJjUEdYfsYb', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 2812, 'output_tokens': 607, 'total_tokens': 3419, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 512}}),
#               ToolMessage(content=[{'type': 'text', 'text': '{\n  "query": "Copenhagen → Doha on 21/12/2026, 1 adult, economy [≤0 stops/sector]",\n  "currency": "EUR",\n  "passengers": {\n    "adults": 1,\n    "children": 0,\n    "infants": 0\n  },\n  "resultsCount": 3,\n  "itineraries": [\n    {\n      "id": "07bb02e8514800008300a83c_0",\n      "price": 700.0,\n      "priceFormatted": "700 EUR",\n      "totalDurationSeconds": 21600,\n      "bookingUrl": "https://kiwi.com/u/tnk32j",\n      "imageId": "doha_qa",\n      "baggage": {\n        "personalItem": 0,\n        "cabinBag": 1,\n        "checkedBag": 0\n      },\n      "outbound": {\n        "from": "CPH",\n        "to": "DOH",\n        "departureTime": "2026-12-21T15:05:00",\n        "arrivalTime": "2026-12-21T23:05:00",\n        "durationSeconds": 21600,\n        "stops": 0,\n        "route": [\n          "CPH",\n          "DOH"\n        ],\n        "cabinClass": "Economy",\n        "segments": [\n          {\n            "from": "CPH",\n            "to": "DOH",\n            "fromCity": "Copenhagen",\n            "toCity": "Doha",\n            "fromName": "Airport Copenhagen",\n            "toName": "Hamad International",\n            "fromCountry": "Denmark",\n            "toCountry": "Qatar",\n            "departureTime": "2026-12-21T15:05:00",\n            "arrivalTime": "2026-12-21T23:05:00",\n            "durationSeconds": 21600,\n            "carrier": "AY",\n            "carrierName": "Finnair",\n            "flightNumber": "AY6700",\n            "cabinClass": "Economy"\n          }\n        ]\n      },\n      "inbound": null\n    },\n    {\n      "id": "07bb02e851480000b436cd56_0",\n      "price": 1240.0,\n      "priceFormatted": "1240 EUR",\n      "totalDurationSeconds": 21600,\n      "bookingUrl": "https://kiwi.com/u/9sy9sh",\n      "imageId": "doha_qa",\n      "baggage": {\n        "personalItem": 1,\n        "cabinBag": 1,\n        "checkedBag": 1\n      },\n      "outbound": {\n        "from": "CPH",\n        "to": "DOH",\n        "departureTime": "2026-12-21T15:05:00",\n        "arrivalTime": "2026-12-21T23:05:00",\n        "durationSeconds": 21600,\n        "stops": 0,\n        "route": [\n          "CPH",\n          "DOH"\n        ],\n        "cabinClass": "Economy",\n        "segments": [\n          {\n            "from": "CPH",\n            "to": "DOH",\n            "fromCity": "Copenhagen",\n            "toCity": "Doha",\n            "fromName": "Airport Copenhagen",\n            "toName": "Hamad International",\n            "fromCountry": "Denmark",\n            "toCountry": "Qatar",\n            "departureTime": "2026-12-21T15:05:00",\n            "arrivalTime": "2026-12-21T23:05:00",\n            "durationSeconds": 21600,\n            "carrier": "QR",\n            "carrierName": "Qatar Airways",\n            "flightNumber": "QR160",\n            "cabinClass": "Economy"\n          }\n        ]\n      },\n      "inbound": null\n    },\n    {\n      "id": "07bb02e8514800009fc38d11_0",\n      "price": 1292.0,\n      "priceFormatted": "1292 EUR",\n      "totalDurationSeconds": 21600,\n      "bookingUrl": "https://kiwi.com/u/usqfnff",\n      "imageId": "doha_qa",\n      "baggage": {\n        "personalItem": 1,\n        "cabinBag": 1,\n        "checkedBag": 1\n      },\n      "outbound": {\n        "from": "CPH",\n        "to": "DOH",\n        "departureTime": "2026-12-21T15:05:00",\n        "arrivalTime": "2026-12-21T23:05:00",\n        "durationSeconds": 21600,\n        "stops": 0,\n        "route": [\n          "CPH",\n          "DOH"\n        ],\n        "cabinClass": "Economy",\n        "segments": [\n          {\n            "from": "CPH",\n            "to": "DOH",\n            "fromCity": "Copenhagen",\n            "toCity": "Doha",\n            "fromName": "Airport Copenhagen",\n            "toName": "Hamad International",\n            "fromCountry": "Denmark",\n            "toCountry": "Qatar",\n            "departureTime": "2026-12-21T15:05:00",\ ...
#               AIMessage(content='Here are the direct (non-stop) options from Copenhagen (CPH) to Doha (DOH) for December 21, 2026. All are one-way.\n\n| Itinerary | Route | Time (local) | Cabin | Price | Booking |\n|---|---|---|---|---|---|\n| Cheapest | CPH → DOH | 21 Dec 2026, 15:05 – 23:05 (6h) | Economy | 700 EUR | https://kiwi.com/u/tnk32j (Finnair AY6700) |\n| Notable | CPH → DOH | 21 Dec 2026, 15:05 – 23:05 (6h) | Economy | 1240 EUR | https://kiwi.com/u/9sy9sh (Qatar Airways QR160) |\n| Alternative | CPH → DOH | 21 Dec 2026, 15:05 – 23:05 (6h) | Economy | 1292 EUR | https://kiwi.com/u/usqfnff (Iberia IB8402) |\n\nBest price: 700 EUR (Finnair AY6700). Shortest duration: all options are 6 hours with direct service.\n\nRecommendation: If you value price, book the 700 EUR Finnair flight. If you prefer a strong airline experience, Qatar Airways is excellent, though higher in price.\n\nNice trip ahead! Fun fact: Doha is home to the Museum of Islamic Art, which sits on an island and features a renowned collection spanning 1,400 years of Islamic art.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 2135, 'prompt_tokens': 4199, 'total_tokens': 6334, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 1792, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 2688}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-EHCNQNJhyreK6IVupuOE7nnoAOku9', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--01a03f44-a9f1-78f3-9b93-1c78aaa41286-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 4199, 'output_tokens': 2135, 'total_tokens': 6334, 'input_token_details': {'audio': 0, 'cache_read': 2688}, 'output_token_details': {'audio': 0, 'reasoning': 1792}})]}

# %%
print(response["messages"][-1].content)
# Out:
# Here are the direct (non-stop) options from Copenhagen (CPH) to Doha (DOH) for December 21, 2026. All are one-way.
#
# | Itinerary | Route | Time (local) | Cabin | Price | Booking |
# |---|---|---|---|---|---|
# | Cheapest | CPH → DOH | 21 Dec 2026, 15:05 – 23:05 (6h) | Economy | 700 EUR | https://kiwi.com/u/tnk32j (Finnair AY6700) |
# | Notable | CPH → DOH | 21 Dec 2026, 15:05 – 23:05 (6h) | Economy | 1240 EUR | https://kiwi.com/u/9sy9sh (Qatar Airways QR160) |
# | Alternative | CPH → DOH | 21 Dec 2026, 15:05 – 23:05 (6h) | Economy | 1292 EUR | https://kiwi.com/u/usqfnff (Iberia IB8402) |
#
# Best price: 700 EUR (Finnair AY6700). Shortest duration: all options are 6 hours with direct service.
#
# Recommendation: If you value price, book the 700 EUR Finnair flight. If you prefer a strong airline experience, Qatar Airways is excellent, though higher in price.
#
# Nice trip ahead! Fun fact: Doha is home to the Museum of Islamic Art, which sits on an island and features a renowned collection spanning 1,400 years of Islamic art.
