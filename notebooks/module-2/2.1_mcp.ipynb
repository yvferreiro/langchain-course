# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
import sys
import asyncio

# Fix for Windows issues in Jupyter notebooks
if sys.platform == "win32":
    # 1. Use ProactorEventLoop for subprocess support
    if not isinstance(asyncio.get_event_loop_policy(), asyncio.WindowsProactorEventLoopPolicy):
        asyncio.set_event_loop_policy(asyncio.WindowsProactorEventLoopPolicy())
    
    # 2. Redirect stderr to avoid fileno() error when launching MCP servers
    if "ipykernel" in sys.modules:
        sys.stderr = sys.__stderr__

# %% [markdown]
# ## Local MCP server

# %%
from langchain_mcp_adapters.client import MultiServerMCPClient

client = MultiServerMCPClient(
    {
        "local_server": {
                "transport": "stdio",
                "command": "python",
                "args": ["resources/2.1_mcp_server.py"],
            }
    }
)

# %%
# get tools
tools = await client.get_tools()

# get resources
resources = await client.get_resources("local_server")

# get prompts
prompt = await client.get_prompt("local_server", "prompt")
prompt = prompt[0].content

# %%
from langchain.agents import create_agent

agent = create_agent(
    model="gpt-5-nano",
    tools=tools,
    system_prompt=prompt
)

# %%
from langchain.messages import HumanMessage

config = {"configurable": {"thread_id": "1"}}

response = await agent.ainvoke(
    {"messages": [HumanMessage(content="Tell me about the langchain-mcp-adapters library")]},
    config=config
)

# %%
from pprint import pprint

pprint(response)
# Out:
# {'messages': [HumanMessage(content='Tell me about the langchain-mcp-adapters library', additional_kwargs={}, response_metadata={}, id='8526db64-73d8-4a45-931c-ce9ea8302cc3'),
#               AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 156, 'prompt_tokens': 271, 'total_tokens': 427, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 128, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-EHCMFlfpzqdnz7ZxLQc19E4nMnn9X', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--01a03f43-85f1-78d3-a7e1-8390f90c7e76-0', tool_calls=[{'name': 'search_web', 'args': {'query': 'langchain-mcp-adapters'}, 'id': 'call_hIfzF5SRitKJ9BWJCzUwt8Ff', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 271, 'output_tokens': 156, 'total_tokens': 427, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 128}}),
#               ToolMessage(content=[{'type': 'text', 'text': '{\n  "query": "langchain-mcp-adapters",\n  "follow_up_questions": null,\n  "answer": null,\n  "images": [],\n  "results": [\n    {\n      "url": "https://github.com/langchain-ai/langchain-mcp-adapters",\n      "title": "LangChain MCP Adapters - GitHub",\n      "content": "## Repository files navigation\\n\\n# LangChain MCP Adapters\\n\\nThis library provides a lightweight wrapper that makes Anthropic Model Context Protocol (MCP) tools compatible with LangChain and LangGraph.\\n\\nNote\\n\\nA JavaScript/TypeScript version of this library is also available at langchainjs.\\n\\n## Features\\n\\n 🛠️ Convert MCP tools into LangChain tools that can be used with LangGraph agents\\n 📦 A client implementation that allows you to connect to multiple MCP servers and load tools from them [...] ```\\nfrom langchain_mcp_adapters client import MultiServerMCPClient from langchain agents import create_agent client = MultiServerMCPClient \\"weather\\" \\"transport\\" \\"http\\" \\"url\\"\\" \\"headers\\" \\"Authorization\\" \\"Bearer YOUR_TOKEN\\"\\"X-Custom-Header\\"\\"custom-value\\" tools = await client get_tools agent = create_agent\\"openai:gpt-4.1\\" tools response = await agent ainvoke \\"messages\\" \\"what is the weather in nyc?\\"\\n``` [...] from langchain_mcp_adapters client import MultiServerMCPClient from langchain agents import create_agent client = MultiServerMCPClient \\"math\\" \\"command\\" \\"python\\"# Make sure to update to the full absolute path to your math_server.py file \\"args\\"\\"/path/to/math_server.py\\" \\"transport\\" \\"stdio\\" \\"weather\\" # Make sure you start your weather server on port 8000 \\"url\\"\\" \\"transport\\" \\"http\\" tools = await client get_tools agent = create_agent\\"openai:gpt-4.1\\" tools math_response = await agent ainvoke",\n      "score": 0.90849644,\n      "raw_content": null,\n      "id": "70886c-00"\n    },\n    {\n      "url": "https://www.getknit.dev/blog/integrating-mcp-with-popular-frameworks-langchain-openagents",\n      "title": "MCP vs LangChain Tools: When to Use Each and How They Work Together (2026)",\n      "content": "This is where the LangChain MCP Adapter steps in. It acts as a middleware bridge that connects LangChain agents to tools exposed by MCP-compliant servers, allowing you to scale tool usage, simplify development, and enforce clean boundaries between agent logic and tooling infrastructure. The LangChain MCP Adapter allows you to use any MCP tool server and auto-wrap its tools as LangChain Tool objects.\\n\\n### How It Works\\n\\n#### Step 1: Initialize MCP Client Session [...] (you\'re running external servers); native LangChain tools don\'t. The LangChain MCP Adapters library bridges both: you can use MCP tools inside LangChain agents without giving up LangChain\'s orchestration features. For production integrations across many platforms, Knit provides pre-built MCP servers that eliminate the need to build and maintain individual tool definitions. [...] that loop. The LangChain MCP Adapters library makes MCP tools directly usable inside LangGraph agents without any manual wrapping.",\n      "score": 0.8900749,\n      "raw_content": null,\n      "id": "df33ee-01"\n    },\n    {\n      "url": "https://npmjs.com/package/@langchain/mcp-adapters",\n      "title": "@langchain/mcp-adapters",\n      "content": "The `useStandardContentBlocks` field determines how individual MCP content blocks are transformed into a structure recognized by LangChain ChatModel providers (e.g. `ChatOpenAI`, `ChatAnthropic`, etc). The `outputHandling` field allows you to specify whether a given type of content should be sent to the LLM, or set aside for some other part of your application to use in some future processing step (e.g. to use a dataframe from a database query in a code execution environment). [...] ## Tool Output Mapping\\n\\n.\\n\\nMCP tools return arrays of content blocks. A content block can contain text, an imag ...
#               AIMessage(content='Here’s a concise overview of the LangChain MCP Adapters library and how it fits into LangChain/LangGraph/LangSmith.\n\nWhat it is\n- A bridge that lets tools exposed via Anthropic Model Context Protocol (MCP) servers be used inside LangChain and LangGraph workflows.\n- It wraps MCP tools as LangChain tools, so you can orchestrate them with LangChain agents and tools.\n- There are implementations for both Python (LangChain) and JavaScript/TypeScript (LangChainJS), and the library is sourced from the LangChain ecosystem.\n\nWhy you’d use it\n- If you already have MCP-compliant servers (tools) you want to reuse in LangChain/LangGraph without writing a lot of glue code.\n- It enables scaling tool usage across many MCP servers and keeps tool logic separate from agent orchestration.\n\nKey features\n- Multi-server support: MultiServerMCPClient lets you connect to multiple MCP servers and load their tools into a single LangChain workflow.\n- Automatic wrapping: MCP tools are automatically wrapped as LangChain tools so they can be invoked by LangChain agents.\n- Optional tool name prefixing: You can prefix tool names with the server name to avoid conflicts when multiple servers expose tools with the same name.\n- Tool call interceptors: Optional interceptors allow you to modify requests/responses to the MCP servers.\n- Content mapping controls (via npm package): MCP tools return content blocks; you can tune how blocks are transformed into LangChain messages with options like useStandardContentBlocks and outputHandling.\n\nCore concepts and components\n- MCP servers and MCP tools: External servers exposing tools using the MCP standard.\n- MultiServerMCPClient: Python class (and its JS equivalent) to connect to MCP servers, load tools, prompts, and resources.\n  - Supports: a connections dictionary, optional callbacks, tool_interceptors, tool_name_prefix, handle_tool_errors.\n- Tool wrapping: MCP tools are presented to LangChain as LangChain Tool objects for use by agents and LangGraph.\n- Tool name management: When multiple servers are used, you can prefix names to avoid collisions.\n- Content blocks and mapping: MCP tools return content blocks (text, images, etc.). You can control how these map to LangChain messages and whether to pass content through to the LLM or handle it separately (via useStandardContentBlocks and outputHandling).\n\nWhere to read more (recommended references)\n- GitHub: LangChain MCP Adapters repository (primary source with code and examples)\n- LangChain Python reference: MultiServerMCPClient (official API reference)\n- npm package page: @langchain/mcp-adapters (configuration options like useStandardContentBlocks and outputHandling)\n- Blog/book articles: tutorials and overviews on using MCP with LangChain and LangGraph (e.g., “Using an existing MCP server with LangChain MCP adapters”)\n\nTypical usage overview (high level)\n- Start by pointing the MCP adapter at your MCP servers (one or many).\n- Load the MCP tools via the adapter (e.g., client.get_tools()) so they appear as LangChain tools.\n- Create a LangChain agent (or LangGraph agent) with an LLM and pass the loaded MCP tools.\n- Run prompts through the agent; the agent can invoke MCP tools just like any other LangChain tool.\n\nA quick, non-conflicting mental model\n- Think of MCP as the tool servers you own or manage.\n- The LangChain MCP Adapters library is the translator/bridge that makes those MCP tools behave like LangChain tools, so they can be orchestrated by LangChain/LangGraph agents and pipelines.\n\nQuestions to tailor help\n- Are you planning to use Python (LangChain) or JavaScript/TypeScript (LangChainJS)?\n- Do you want to connect to a single MCP server or multiple servers?\n- Do you need tool name prefixing or specific content-block mapping behavior for your use case?\n- Would you like a minimal example (pseudo-code) to get you started in Python or JS?\n\nIf you’d like, tell me your language and whether you ...

# %% [markdown]
# ## Online MCP

# %%
client = MultiServerMCPClient(
    {
        "time": {
            "transport": "stdio",
            "command": "uv",
            "args": [
                "run",
                "python",
                "-m",
                "mcp_server_time",
                "--local-timezone=America/New_York"
            ]
        }
    }
)

tools = await client.get_tools()

# %%
agent = create_agent(
    model="gpt-5-nano",
    tools=tools,
)

# %%
question = HumanMessage(content="What time is it?")

response = await agent.ainvoke(
    {"messages": [question]}
)

pprint(response)
