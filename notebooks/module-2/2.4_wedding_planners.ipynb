# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %% [markdown]
# # 2.4 Wedding Planner
# In this lab you will build a multi-agent wedding planner.
#
# > Note: This lab has been updated since filming to make the agent performance more robust to errors and to limit run time. In particular: 1) added error handling for MCP failures, 2) limited the number of searches. It's worth noting that, where possible, tool errors should be returned to the agent rather than failing so that the agent can adjust its invocation and try again.

# %% [markdown]
# ## Setup Tools

# %%
import asyncio

from langchain_mcp_adapters.client import MultiServerMCPClient
from mcp.shared.exceptions import McpError
from mcp.types import CallToolResult, TextContent

RETRYABLE_MCP_CODES = {-32603}

class RetryMCPInterceptor:
    """Intercept MCP tool calls: retry transient failures, surface all errors gracefully.

    - Retryable McpError codes (e.g. -32603): retry with exponential backoff.
    - Non-retryable McpError codes (e.g. -32602): return error message immediately.
    - Any other exception (fetch failed, network errors, etc.): retry then return error message.
    """

    def __init__(self, max_retries: int = 3):
        self.max_retries = max_retries

    async def __call__(self, request, handler):
        last_error = None
        for attempt in range(self.max_retries):
            try:
                return await handler(request)
            except McpError as exc:
                last_error = exc
                print(f"[MCP interceptor] {type(exc).__name__} on {request.name} "
                      f"(code {exc.error.code}, attempt {attempt+1}/{self.max_retries}): {exc}")
                if exc.error.code not in RETRYABLE_MCP_CODES:
                    return CallToolResult(
                        content=[TextContent(type="text", text=f"Tool call failed (non-retryable): {exc}")],
                        isError=False,
                    )
            except Exception as exc:
                last_error = exc
                print(f"[MCP interceptor] {type(exc).__name__} on {request.name} "
                      f"(attempt {attempt+1}/{self.max_retries}): {exc}")

            if attempt < self.max_retries - 1:
                await asyncio.sleep(2 ** attempt)

        print(f"[MCP interceptor] all {self.max_retries} retries exhausted for {request.name}")
        return CallToolResult(
            content=[TextContent(type="text", text=f"Tool call failed after {self.max_retries} attempts: {last_error}")],
            isError=False,
        )

client = MultiServerMCPClient(
    {
        "travel_server": {
                "transport": "streamable_http",
                "url": "https://mcp.kiwi.com"
            }
    },
    tool_interceptors=[RetryMCPInterceptor()],
)

tools = await client.get_tools()

# %%
from typing import Dict, Any
from tavily import TavilyClient
from langchain.tools import tool

tavily_client = TavilyClient()

@tool
def web_search(query: str, search_number: int, max_search_number: int) -> Dict[str, Any]:
    """Search the web for information. You must track your search count by providing
    search_number (starting at 1) and max_search_number on every call.
    Queries must use only plain text characters. Do not use accented or special characters     
      (e.g., use 'capacite' instead of 'capacité').
    """
    if search_number > max_search_number:
        return {"message": "Search limit reached. Please summarize your findings and provide your final answer."}
    try:
        return tavily_client.search(query)
    except Exception as e:
        return {"error": str(e)}

# %%
from langchain_community.utilities import SQLDatabase

db = SQLDatabase.from_uri("sqlite:///resources/Chinook.db")

@tool
def query_playlist_db(query: str) -> str:

    """Query the database for playlist information"""

    try:
        return db.run(query)
    except Exception as e:
        return f"Error querying database: {e}"
# Out:
# /var/folders/g0/r571pkwj6973dlq1m_v76wp40000gn/T/ipykernel_12714/2549610831.py:1: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.utilities import SQLDatabase

# %% [markdown]
# ## Create State

# %%
from langchain.agents import AgentState

class WeddingState(AgentState):
    origin: str
    destination: str
    guest_count: str
    genre: str

# %% [markdown]
# ## Create Subagents

# %%
from langchain.agents import create_agent

# Travel agent
travel_agent = create_agent(
    model="gpt-5-nano",
    tools=tools,
    system_prompt="""
    You are a travel agent. Search for flights to the desired destination wedding location.
    You are not allowed to ask any more follow up questions, you must find the best flight options based on the following criteria:
    - Price (lowest, economy class)
    - Duration (shortest)
    - Date (time of year which you believe is best for a wedding at this location)
    To make things easy, only look for one ticket, one way.
    You may need to make multiple searches to iteratively find the best options.
    You will be given no extra information, only the origin and destination. It is your job to think critically about the best options.
    If the MCP tool fails, returns malformed output, or does not give you usable flight results, try the tool again.
    Once you have found the best options, let the user know your shortlist of options.
    """
)

# %%
# Venue agent
venue_agent = create_agent(
    model="gpt-5-nano",
    tools=[web_search],
    system_prompt="""
    You are a venue specialist. Search for venues in the desired location, and with the desired capacity.
    You are not allowed to ask any more follow up questions, you must find the best venue options based on the following criteria:
    - Price (lowest)
    - Capacity (exact match)
    - Reviews (highest)
    You may need to make multiple searches to iteratively find the best options. 
    You have a suggested limit of 12 web searches. Count every web_search call you make.
    After 12 searches, you should stop searching and summarize the best options you have
    found so far.
    """
)

# %%
# Playlist agent
playlist_agent = create_agent(
    model="gpt-5-nano",
    tools=[query_playlist_db],
    system_prompt="""
    You are a playlist specialist. Query the sql database and curate the perfect playlist for a wedding given a genre.
    Once you have your playlist, calculate the total duration and cost of the playlist, each song has an associated price.
    If you run into errors when querying the database, try to fix them by making changes to the query.
    Do not come back empty handed, keep trying to query the db until you find a list of songs.

    This is a SQLite database. Before writing any data queries, first discover the schema.
    """
)

# %% [markdown]
# ## Main Coordinator

# %%
from langchain.tools import ToolRuntime
from langchain.messages import HumanMessage, ToolMessage
from langgraph.types import Command

@tool
async def search_flights(runtime: ToolRuntime) -> str:
    """Travel agent searches for flights to the desired destination wedding location."""
    origin = runtime.state["origin"]
    destination = runtime.state["destination"]
    response = await travel_agent.ainvoke({"messages": [HumanMessage(content=f"Find flights from {origin} to {destination}")]})
    return response['messages'][-1].content

@tool
def search_venues(runtime: ToolRuntime) -> str:
    """Venue agent chooses the best venue for the given location and capacity."""
    destination = runtime.state["destination"]
    capacity = runtime.state["guest_count"]
    query = f"Find wedding venues in {destination} for {capacity} guests"
    response = venue_agent.invoke({"messages": [HumanMessage(content=query)]})
    return response['messages'][-1].content

@tool
def suggest_playlist(runtime: ToolRuntime) -> str:
    """Playlist agent curates the perfect playlist for the given genre."""
    genre = runtime.state["genre"]
    query = f"Find {genre} tracks for wedding playlist"
    response = playlist_agent.invoke({"messages": [HumanMessage(content=query)]})
    return response['messages'][-1].content

@tool
def update_state(origin: str, destination: str, guest_count: str, genre: str, runtime: ToolRuntime) -> str:
    """Update the state when you know all of the values: origin, destination, guest_count, genre. 
    This tool must be called alone, without any other tool calls. It must complete and return to make,
    the information available to other tools."""
    return Command(update={
        "origin": origin, 
        "destination": destination, 
        "guest_count": guest_count, 
        "genre": genre, 
        "messages": [ToolMessage("Successfully updated state", tool_call_id=runtime.tool_call_id)]}
        )

# %%
from langchain.agents import create_agent

coordinator = create_agent(
    model="gpt-5-nano",
    tools=[search_flights, search_venues, suggest_playlist, update_state],
    state_schema=WeddingState,
    system_prompt="""
    You are a wedding coordinator. 
    First find all the information you need to update the state. When you have the information, update the state.
    Once that has completed and returned, you can delegate the tasks 
    to your specialists for flights, venues, and playlists.
    Once you have received their answers, coordinate the perfect wedding for me.
    """
)

# %% [markdown]
# ## Test

# %%
from langchain.messages import HumanMessage

response = await coordinator.ainvoke(
    {
        "messages": [HumanMessage(content="I'm from Amsterdam and I'd like a wedding in Toledo, Spain for 150 guests, venezuelan or latin-genre")],
    },
    config={"tags": ["WP"], "recursion_limit": 40},  #tag traces to make them easy to find in Langsmith. Increase number of steps the agent can take to 40.
)

# %%
from pprint import pprint

pprint(response)
# Out:
# {'destination': 'Toledo, Spain',
#  'genre': 'Latin - Venezuelan-inspired',
#  'guest_count': '150',
#  'messages': [HumanMessage(content="I'm from Amsterdam and I'd like a wedding in Toledo, Spain for 150 guests, venezuelan or latin-genre", additional_kwargs={}, response_metadata={}, id='5bb33393-5474-4215-a17c-729b71857ff3'),
#               AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 875, 'prompt_tokens': 342, 'total_tokens': 1217, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 832, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-EHCaBJ08yEsyfmvio4spiOgBz0Fyx', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--01a03f50-bc16-7f60-b23e-8fe5aad24356-0', tool_calls=[{'name': 'update_state', 'args': {'origin': 'Amsterdam', 'destination': 'Toledo, Spain', 'guest_count': '150', 'genre': 'Latin - Venezuelan-inspired'}, 'id': 'call_jiMraB2KIDs0QMTffLAo5EBW', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 342, 'output_tokens': 875, 'total_tokens': 1217, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 832}}),
#               ToolMessage(content='Successfully updated state', name='update_state', id='b96fec58-a877-4a95-ac36-05595d3de857', tool_call_id='call_jiMraB2KIDs0QMTffLAo5EBW'),
#               AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 254, 'prompt_tokens': 393, 'total_tokens': 647, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 192, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-EHCaHf6fYTP2ckYdjEjqt9cVNvZyS', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--01a03f50-d52d-7693-bb9f-75808b25d649-0', tool_calls=[{'name': 'search_flights', 'args': {}, 'id': 'call_tWw8xeRMQkFcLUAc3v2fzgGn', 'type': 'tool_call'}, {'name': 'search_venues', 'args': {}, 'id': 'call_jyI9eAsaUWHZOhP7iVwRYhCp', 'type': 'tool_call'}, {'name': 'suggest_playlist', 'args': {}, 'id': 'call_clVtk4OrgFH3OPPiLmPBkImw', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 393, 'output_tokens': 254, 'total_tokens': 647, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 192}}),
#               ToolMessage(content='Here are the best one-way flight options from Amsterdam to Toledo (Spain) by routing via the nearest major airport (Madrid–MAD is the practical destination since Toledo doesn’t have a large commercial airport). I focused on direct AMS → MAD options (shortest and cheapest) and a good one-stop backup.\n\nCheapest and shortest at a glance (direct AMS → MAD)\n- Route: AMS → MAD\n  - Times: 11:00 → 13:45 (2h45m), Nonstop, Economy\n  - Price: 115 EUR\n  - Booking: https://kiwi.com/u/t8gcccn\n\n- Route: AMS → MAD\n  - Times: 19:00 → 21:45 (2h45m), Nonstop, Economy\n  - Price: 115 EUR\n  - Booking: https://kiwi.com/u/6fxrn5\n\nOther notable option (one-stop, slightly longer and still affordable)\n- Route: AMS → PMI → MAD\n  - Times: 15:00 → 22:45 (7h45m), 1 stop, Economy\n  - Price: 119 EUR\n  - Booking: https://kiwi.com/u/nu6v8dp\n\nNotes and best-date guidance\n- Best practical plan for Toledo: Fly Amsterdam to Madrid (MAD), then transfer to Toledo by train or car. The high-speed train from Madrid to Toledo is about 30–40 minutes, and Madrid Airport to the city center is straightforward by rail or taxi.\n- Best time of year for a wedding in Toledo: late spring to early summer (roughly May–June) and again in early autumn (September) tend to have pleasant weather and long daylight. If you’re looking at the flight options above, June 2027 departures (e.g., June 15) align nicely with ideal Toledo weather.\n\nRecommendation\n- If you want the absolute lowest price and shortest travel time: choose 11:00–13:45 on June 15, 2027 (115 EUR) or the 19:00–21:45 option on the same day (115 EUR). Both are nonstop AMS → MAD and land you in good shape to reach Toledo that day.\n- If you’re flexible and want a slightly different schedule with similar price: consider the 15:00 departure via PMI for 119 EUR.\n\nWishing you a fabulous wedding trip! Fun fact: Toledo is known as the "City of Three Cultures" because Christians, Muslims, and Jews lived there together for centuries, shaping its art, architecture, and history. Enjoy your trip planning!', name='search_flights', id='7b507296-002a-4eba-8f3f-a98ce09bd01c', tool_call_id='call_tWw8xeRMQkFcLUAc3v2fzgGn'),
#               ToolMessage(content='Here are the best matches I found for exactly 150 guests in Toledo, Spain (using the 12-search limit):\n\n- Cigarral de Caravantes (Toledo)\n  - Capacity: 150 guests (the venue’s restaurant is listed with capacity for 150 comensales)\n  - What it is: A historic fincas complex with a 3-star hotel on site (17 rooms) and an on-site restaurant\n  - Source: CelebRents listing that describes the complex and notes the restaurant capacity at 150\n  - Price: Not publicly listed\n  - Reviews: Not publicly listed in that source\n\nNotes and near-matches (not exact 150, but often used for a 150 guest wedding):\n- Cigarral del Ángel (Toledo)\n  - Capacity: Up to 300 guests\n  - Source: Various venue roundups mentioning this as a Toledo option\n  - Price: Not publicly listed\n- Cigarral de las Mercedes (Toledo)\n  - Capacity: 450 guests\n  - Source: Multiple listings; price starts higher in general\n  - Price: Not publicly listed\n  - Reviews: Not consolidated in the sources I pulled\n\nThere are several Toledo fincas and venue guides (eg, Frans Solana’s “Las mejores fincas y cigarrales de Toledo” and Bodas.net listings) that note venues capable of hosting around 150 guests, but they don’t all provide a single explicit 150-capacity venue with a public price. The clearest exact-capacity match I found is Cigarral de Caravantes.\n\nIf you’d like, I can pull live quotes and contact details for Cigarral de Caravantes and the near-match venues to compare availability and exact pricing.', name='search_venues', id='a4784bfe-1d1b-4375-9745-d01d0a13a1ed', tool_call_id='call_jyI9eAsaUWHZOhP7iVwRYhCp'),
#               ToolMessage(content='I looked for Latin tracks with a Venezuelan inspiration, but the current catalog doesn’t show Venezuelan artists or explicitly Venezuelan-inspired entries. The Latin genre entries are largely Brazilian artists (e.g., Antônio Carlos Jobim, Caetano Veloso, Chico Buarque, Djavan, Elis Regina, Ed Motta). I can either:\n\n- broaden to general Latin wedding vibes (romantic danceable tracks in Latin genres), or\n- add Venezuelan or Salsa/Mandamba/Mrenchue-type tracks from another source if you provide access, or\n- include Brazilian/Congruent Latin tracks that pair well for a Latin-flavored wedding vibe.\n\nHere’s a curated Latin-wusion wedding playlist from the current catalog (12 tracks) that flows well for a wedding reception: romantic, smooth, and danceable.\n\nLatin wedding playlist (12 tracks)\n- 391 Garota De Ipanema — Antônio Carlos Jobim — Latin — 4:39 — $0.99\n- 396 Alô Alô Marciano — Antônio Carlos Jobim — Latin — 3:58 — $0.99\n- 399 Abrir A Porta — Antônio Carlos Jobim — Latin — 4:32 — $0.99\n- 400 Alice — Antônio Carlos Jobim — Latin — 2:46 — $0.99\n- 397 Linha Do Horizonte — Antônio Carlos Jobim — Latin — 4:39 — $0.99\n- 405 Santo Antonio — Antônio Carlos Jobim — Latin — 2:43 — $0.99\n- 406 Por Você — Antônio Carlos Jobim — Latin — 3:26 — $0.99\n- 407 Só Tinha De Ser Com Você — Antônio Carlos Jobim — Latin — 6:30 — $0.99\n- 394 Tanto Tempo — Antônio Carlos Jobim — Latin — 2:50 — $0.99\n- 395 Eu Vim Da Bahia - Live — Antônio Carlos Jobim — Latin — 2:38 — $0.99\n- 402 Um Jantar Pra Dois — Antônio Carlos Jobim — Latin — 3:58 — $0.99\n- 401 Momentos Que Marcam — Antônio Carlos Jobim — Latin — 4:40 — $0.99\n\nTotal duration\n- Sum of track durations: 2,839,114 ms ≈ 2,839.1 seconds ≈ 47 minutes 19 seconds\n\nTotal cost\n- 12 tracks × $0.99 each = $11.88\n\nNotes and next steps\n- If you want true Venezuelan-inspired tracks, I can chase a Venezuelan/Latin Salsa/merengue/bachata subset from a separate catalog or you can share a list of Venezuelan artists you want included.\n- If you’d prefer a more explicit “Venezuela-inspired Latin” vibe (e.g., Venezuelan artists or Venezuelan-influenced salsa/merengue), tell me your preferred tempo, language balance (Spanish vs. Portuguese), and whether you want more dance-floor tracks or more romantic ballads, and I’ll tailor the search and playlist accordingly.\n\nWould you like me to try to pull in Venezuelan-inspired options from a broader source, or adjust the playlist to include more danceable Salsa/Merengue/Bachata tracks in Latin style?', name='suggest_playlist', id='9a5584f5-292f-45e8-9605-2a27bb5a8d82', tool_call_id='call_clVtk4OrgFH3OPPiLmPBkImw'),
#               AIMessage(content='Fantastic. I’ve updated your profile and gathered initial options. Here’s a concise briefing and the next steps.\n\nWhat I’ve gathered so far\n- Origin: Amsterdam\n- Destination: Toledo, Spain\n- Guest count: 150\n- Music vibe: Latin with Venezuelan-inspired elements (seeking a Latin wedding vibe, possibly with salsa/merengue/bachata)\n\nTravel options (Amsterdam to Toledo workflow)\n- Best-practice route: AMS → MAD (Madrid), then transfer to Toledo (train or car)\n- Direct AMS → MAD options (shortest, fastest, cheapest)\n  - Option 1: 11:00 – 13:45, nonstop, Economy, 115 EUR\n  - Option 2: 19:00 – 21:45, nonstop, Economy, 115 EUR\n- One-stop backup option\n  - AMS → PMI → MAD, 7h45m total, 119 EUR\nNotes:\n- From Madrid to Toledo, high-speed train (AVE) or quick transfer by rail taxi will get you into Toledo in about 30–40 minutes.\n- For a wedding, many couples fly in the day before or morning of, then head to Toledo to settle in. We can tailor timing around ceremony start times and venue access.\n\nVenue options in Toledo (capacity near 150)\n- Cigarral de Caravantes (Toledo)\n  - Capacity: 150 guests (fits your guest count)\n  - On-site hotel: 17 rooms\n  - On-site restaurant\n  - Notes: This is the clearest exact-capacity match with published details\n  - Price: Not publicly listed; we should request a formal quote and availability\n- Near-match options (capacity and vibe)\n  - Cigarral del Ángel (Toledo) — up to 300 guests\n  - Cigarral de las Mercedes (Toledo) — up to 450 guests\n  - These can be alternatives if Caravantes isn’t available or if you want a larger, different setting\nNext step for venues: I can reach out for live availability and formal quotes for Cigarral de Caravantes (and compare with the alternatives above) once you confirm your preferred wedding date window.\n\nMusic playlist direction (Venezuela/Latin vibe)\n- Current result set leaned toward Latin jazz standards (e.g., Jobim), which isn’t a perfect Venezuelan-focused lineup.\n- Plan to tailor with true Venezuelan and broader Latin-dusion tracks (salsa, merengue, bachata, Latin pop ballads) to fit the moments: welcome, dinner, dancing, last dance.\n- I can pull a Venezuelan/Latin-inspired setlist and also craft a dance-friendly dance-floor portion with well-known Latin artists and local Spanish picks.\n\nProposed next steps (quick and clear)\n1) Pick a potential wedding date window (month or specific date) and desired ceremony vs. reception timing.\n2) Confirm if Cigarral de Caravantes is your preferred venue, or if you’d like me to compare the other two options as backups.\n3) Confirm your flight preference (best price vs. fastest flight) and how many guests will be booking individually vs. via group arrangements (if you want, I can quote group rates).\n4) Tell me your vibe for the playlist:\n   - Do you want a Venezuelan core (Salsa, Merengue, Bachata, Venezuelan artists) plus Latin-pop for crossover appeal?\n   - Any must-have artists or songs to include or avoid?\n5) Share any budget ranges for venue, travel, and other services so I can tailor quotes accordingly.\n\nWould you like me to proceed with:\n- Holding/quoting Cigarral de Caravantes for your target date and presenting a couple of backup venues if needed?\n- Pulling live flight quotes (AMS↔MAD with the best date-window you have in mind) and arranging a group-booking plan if you want?\n- Building a Venezuelan/Latin-inspired playlist draft now, and then refining it with your feedback?\n\nIf you provide your preferred date window, I’ll start locking in quotes and availability and keep you posted with clear options.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 2462, 'prompt_tokens': 2090, 'total_tokens': 4552, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 1600, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tok ...
#  'origin': 'Amsterdam'}

# %%
print(response["messages"][-1].content)
# Out:
# Fantastic. I’ve updated your profile and gathered initial options. Here’s a concise briefing and the next steps.
#
# What I’ve gathered so far
# - Origin: Amsterdam
# - Destination: Toledo, Spain
# - Guest count: 150
# - Music vibe: Latin with Venezuelan-inspired elements (seeking a Latin wedding vibe, possibly with salsa/merengue/bachata)
#
# Travel options (Amsterdam to Toledo workflow)
# - Best-practice route: AMS → MAD (Madrid), then transfer to Toledo (train or car)
# - Direct AMS → MAD options (shortest, fastest, cheapest)
#   - Option 1: 11:00 – 13:45, nonstop, Economy, 115 EUR
#   - Option 2: 19:00 – 21:45, nonstop, Economy, 115 EUR
# - One-stop backup option
#   - AMS → PMI → MAD, 7h45m total, 119 EUR
# Notes:
# - From Madrid to Toledo, high-speed train (AVE) or quick transfer by rail taxi will get you into Toledo in about 30–40 minutes.
# - For a wedding, many couples fly in the day before or morning of, then head to Toledo to settle in. We can tailor timing around ceremony start times and venue access.
#
# Venue options in Toledo (capacity near 150)
# - Cigarral de Caravantes (Toledo)
#   - Capacity: 150 guests (fits your guest count)
#   - On-site hotel: 17 rooms
#   - On-site restaurant
#   - Notes: This is the clearest exact-capacity match with published details
#   - Price: Not publicly listed; we should request a formal quote and availability
# - Near-match options (capacity and vibe)
#   - Cigarral del Ángel (Toledo) — up to 300 guests
#   - Cigarral de las Mercedes (Toledo) — up to 450 guests
#   - These can be alternatives if Caravantes isn’t available or if you want a larger, different setting
# Next step for venues: I can reach out for live availability and formal quotes for Cigarral de Caravantes (and compare with the alternatives above) once you confirm your preferred wedding date window.
#
# Music playlist direction (Venezuela/Latin vibe)
# - Current result set leaned toward Latin jazz standards (e.g., Jobim), which isn’t a perfect Venezuelan-focused lineup.
# - Plan to tailor with true Venezuelan and broader Latin-dusion tracks (salsa, merengue, bachata, Latin pop ballads) to fit the moments: welcome, dinner, dancing, last dance.
# - I can pull a Venezuelan/Latin-inspired setlist and also craft a dance-friendly dance-floor portion with well-known Latin artists and local Spanish picks.
#
# Proposed next steps (quick and clear)
# 1) Pick a potential wedding date window (month or specific date) and desired ceremony vs. reception timing.
# 2) Confirm if Cigarral de Caravantes is your preferred venue, or if you’d like me to compare the other two options as backups.
# 3) Confirm your flight preference (best price vs. fastest flight) and how many guests will be booking individually vs. via group arrangements (if you want, I can quote group rates).
# 4) Tell me your vibe for the playlist:
#    - Do you want a Venezuelan core (Salsa, Merengue, Bachata, Venezuelan artists) plus Latin-pop for crossover appeal?
#    - Any must-have artists or songs to include or avoid?
# 5) Share any budget ranges for venue, travel, and other services so I can tailor quotes accordingly.
#
# Would you like me to proceed with:
# - Holding/quoting Cigarral de Caravantes for your target date and presenting a couple of backup venues if needed?
# - Pulling live flight quotes (AMS↔MAD with the best date-window you have in mind) and arranging a group-booking plan if you want?
# - Building a Venezuelan/Latin-inspired playlist draft now, and then refining it with your feedback?
#
# If you provide your preferred date window, I’ll start locking in quotes and availability and keep you posted with clear options.

# %% [markdown]
# link to trace: https://smith.langchain.com/public/7b5fe668-d3e3-4af4-b513-a8cacc0c9e84/r
