# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain.tools import tool
from typing import Dict, Any
from tavily import TavilyClient

tavily_client = TavilyClient()

@tool
def web_search(query: str) -> Dict[str, Any]:

    """Search the web for information"""

    return tavily_client.search(query)

# %%
system_prompt = """

You are a personal chef. The user will give you a list of ingredients they have left over in their house.

Using the web search tool, search the web for recipes that can be made with the ingredients they have.

Return recipe suggestions and eventually the recipe instructions to the user, if requested.

"""

# %%
from langchain.agents import create_agent
from langgraph.checkpoint.memory import InMemorySaver

agent = create_agent(
    model="gpt-5-nano",
    tools=[web_search],
    system_prompt=system_prompt,
    checkpointer=InMemorySaver()
)

# %%
from langchain.messages import HumanMessage

config = {"configurable": {"thread_id": "1"}}

response = agent.invoke(
    {"messages": [HumanMessage(content="I have some leftover carrots and celery. What can I make?")]},
    config
)

print(response['messages'][-1].content)
# Out:
# Nice—carrots and celery are classics for cheap, flavorful meals. Here are solid recipe ideas you can make with just those (plus a few pantry staples). Tell me which you want full instructions for and I’ll pull a full recipe.
#
# 1) Carrot-Celery Soup (vegan-friendly)
# - Why: Lean, comforting, and quick.
# - Rough idea: Sauté onion, carrot, celery in oil; add garlic; add tomatoes or stock; simmer 15–20 minutes; blend until smooth; season with salt, pepper, and a squeeze of lemon.
# - Quick tweaks: add a potato for creaminess, or a splash of coconut milk or dairy if you like.
#
# 2) Carrot-Celery Slaw (crunchy side or topping)
# - Why: Great make-ahead side, works with sandwich or bowls.
# - Rough idea: Shred carrots and celery; whisk a simple dressing (olive oil, lemon or vinegar, a touch of mustard or honey, salt, pepper); toss with the veg; optional add apple, walnuts, or yogurt for creaminess.
# - Quick tweaks: add some chopped herbs or a pinch of chili flakes for zing.
#
# 3) Simple Vegetable Stock (base for soups, stews, risottos)
# - Why: Stock is incredibly versatile and can be used in many dishes.
# - Rough idea: Sauté chopped carrot, celery, and onion in oil; add water (or water plus a splash of soy/stock), a bay leaf, peppercorns; simmer 20–40 minutes; strain.
# - Quick tweaks: freeze in ice-cube trays for easy future use; add garlic or herbs if you have them.
#
# 4) Mirepoix-based Base for Soups or Braises
# - Why: A flavor-building starter used in many dishes.
# - Rough idea: Dice carrot, celery, and onion; gently cook in oil or butter until soft and slightly golden; use as the flavor base for any soup, stew, or sauce (you can then add other ingredients you have).
# - Quick tweaks: keep it simple or brown it for deeper flavor.
#
# If you’d like, I can pull full, step-by-step recipes for any of these (or tailor one to what else you have on hand, like onions, garlic, tomatoes, stock, lemon, herbs, or dairy). Which option would you like to start with?

# %%
from pprint import pprint

pprint(response)
# Out:
# {'messages': [HumanMessage(content='I have some leftover carrots and celery. What can I make?', additional_kwargs={}, response_metadata={}, id='f5620821-99f7-4bc6-bd6e-50b7f5e95399'),
#               AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 1082, 'prompt_tokens': 199, 'total_tokens': 1281, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 960, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-EHBGWMsmEXx6czY68dzgdF3kvtYb4', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--01a03f03-7b66-7432-b2cc-e18db185f58a-0', tool_calls=[{'name': 'web_search', 'args': {'query': 'carrot and celery soup recipe'}, 'id': 'call_I1F15v70Zs1XQyqf2QEVXrh7', 'type': 'tool_call'}, {'name': 'web_search', 'args': {'parameters': {'query': 'carrot celery juice recipe'}}, 'id': 'call_OOqnZ7FV5WYRL0HDW5L2ANNB', 'type': 'tool_call'}, {'name': 'web_search', 'args': {'query': 'carrot celery slaw recipe'}, 'id': 'call_TG2KGWUf08cIdbXE1M81RzRK', 'type': 'tool_call'}, {'name': 'web_search', 'args': {'query': 'vegetable stock carrot celery'}, 'id': 'call_E4g6jpxZ2MMofopzWaQ0zaeY', 'type': 'tool_call'}, {'name': 'web_search', 'args': {'query': 'mirepoix ingredients carrot celery recipe'}, 'id': 'call_9Od04DDEzOXDa6brSlPvHfEt', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 199, 'output_tokens': 1082, 'total_tokens': 1281, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 960}}),
#               ToolMessage(content='{"query": "carrot and celery soup recipe", "follow_up_questions": null, "answer": null, "images": [], "results": [{"url": "https://www.sizzlingtastebuds.com/carrot-celery-soup", "title": "Carrot Celery Soup - Vegan and Gluten Free", "content": "What you need to make Carrot + Celery Soup · 1 carrot (large, or 2 medium) · 4 tomatoes · 5-6 stalks Celery · 1 onion (large) · 2 cloves (garlic) · 1", "score": 0.90692574, "raw_content": null, "id": "5f1429-00"}, {"url": "https://www.walderwellness.com/carrot-celery-soup", "title": "Healthy Carrot Celery Soup (Blended) - Walder Wellness", "content": "This simple carrot celery soup is seasoned with onions, garlic, herbs, and lemon juice. It\'s light, fresh, and ready in about 30 minutes!", "score": 0.8377398, "raw_content": null, "id": "d029f3-01"}, {"url": "https://plantbasedfolk.com/carrot-and-celery-soup", "title": "Light and Delicious Carrot and celery soup (Easy & Vegan)", "content": "This carrot and celery soup recipe is light, healthy and delicious. This vegan soup recipe is ready in 30 minutes. Perfect for warming up.", "score": 0.834852, "raw_content": null, "id": "f648ae-02"}, {"url": "https://thewholecook.com/vegetable-soup", "title": "30 Minute Vegetable Soup - The Whole Cook", "content": "Start by sautéing the onion, celery, and carrots in a little oil. Once those veggies are close to tender, add the minced garlic. Stir and sauté until the garlic is golden in color, about one minute. [...] Now add balsamic vinegar to the skillet and scrape up any bits of onion or garlic that are stuck to the bottom of the pan. Add in remaining ingredients except for peas. Stir. Bring to a boil and then reduce heat, cover, and simmer for 10 minutes. Now add the peas and simmer for another 5 to 10 minutes, until all veggies are tender.\\n\\n## How to customize this soup [...] To keep this truly veggie-focused I’m using a vegetable broth. (You can of course use a beef or chicken stock if you like.) To really amp up the flavor and add tons of richness we’re including a bit of balsamic vinegar and tomato paste. These two additions make a huge difference. And then plenty of fresh vegetables make this a truly satiating meal. I bet you love it.\\n\\nFor this recipe you’ll need (full list of ingredients and instructions are in the recipe card below):", "score": 0.82117355, "raw_content": null, "id": "4c5305-03"}, {"url": "https://theclevermeal.com/carrot-and-celery-soup", "title": "Carrot and celery soup", "content": "This slightly spiced carrot and celery soup is flavored with ginger and cinnamon and brightened with fresh lemon. It\'s light and delicious.", "score": 0.75377536, "raw_content": null, "id": "7776f0-04"}], "response_time": 0.0, "request_id": "def5173b-6aa0-4810-baa3-41cfef61eb5b"}', name='web_search', id='2a64770f-7446-41bd-a706-305603038c72', tool_call_id='call_I1F15v70Zs1XQyqf2QEVXrh7'),
#               ToolMessage(content="Error invoking tool 'web_search' with kwargs {'parameters': {'query': 'carrot celery juice recipe'}} with error:\n query: Field required\n Please fix the error and try again.", name='web_search', id='01a6669e-3bbf-4096-b973-abcaac14f659', tool_call_id='call_OOqnZ7FV5WYRL0HDW5L2ANNB', status='error'),
#               ToolMessage(content='{"query": "carrot celery slaw recipe", "follow_up_questions": null, "answer": null, "images": [], "results": [{"url": "https://diningwithdebbie.net/2014/03/14/apple-celery-carrot-slaw", "title": "Apple-Celery-Carrot Slaw", "content": "Mix olive oil, mustard, vinegar, honey, celery seeds, salt, and black pepper. Combine the celery, carrot, apple and walnut and mix thoroughly", "score": 0.88705814, "raw_content": null, "id": "55f84b-00"}, {"url": "https://www.essexgirlcookshealthy.com/carrot-slaw-celery", "title": "Carrot Slaw with Celery", "content": "Ingredients · 6 Carrots · 2Sticks Celery · Parsley (or other fresh herbs) · 2 tbsp 0% Yoghurt · 1 or 2 tsp Homemade Mayonnaise · Half a clove Garlic · Juice of half a", "score": 0.88705814, "raw_content": null, "id": "09b18d-01"}, {"url": "https://www.foodandwinechickie.com/2018/06/23/tangy-carrot-and-celery-slaw", "title": "Tangy Carrot and Celery Slaw - Food & Wine Chickie Insider", "content": "In a medium bowl, combine the mayonnaise, sliced celery, scallions, grated carrots, chopped piquante peppers and vinegar. Drizzle with olive", "score": 0.8839694, "raw_content": null, "id": "6e7cbc-02"}, {"url": "https://myeverydaytable.com/celery-carrot-and-blue-cheese-coleslaw-recipe", "title": "Celery, Carrot, & Blue Cheese Coleslaw Recipe", "content": "Slice celery, carrots, and green onion. In a medium bowl, whisk together olive oil, vinegar, honey, salt, and pepper. To the bowl, add in", "score": 0.8834878, "raw_content": null, "id": "e3539d-03"}, {"url": "https://iheartumami.com/asian-carrot-celery-slaw", "title": "Asian Carrot-Celery Slaw", "content": "Julienned carrots and celery are lightly blanched, then tossed with toasted sesame oil, ginger, garlic, and white pepper. Prep: 15 mins Cook: 1", "score": 0.853046, "raw_content": null, "id": "21a6d3-04"}], "response_time": 1.49, "request_id": "b7b0daef-8913-4425-aebd-5e75148a582e"}', name='web_search', id='782debe4-2b46-4f52-b5e5-9ed688bf7166', tool_call_id='call_TG2KGWUf08cIdbXE1M81RzRK'),
#               ToolMessage(content='{"query": "vegetable stock carrot celery", "follow_up_questions": null, "answer": null, "images": [], "results": [{"url": "https://food52.com/recipes/1385-easy-everyday-vegetable-stock", "title": "Easy Everyday Vegetable Stock - Food52", "content": "## Directions\\n\\nHeat a deep stock pot over medium flame. Add oil, then toss in celery, carrots, onion, garlic and other vegetables you\'re using. Saute for 5 to 7 minutes, until the carrots begin to caramelize and the mixture becomes very fragrant.\\n\\nAdd the bay leaf, parsley, peppercorns and salt. Stir to mix well, then slowly pour in the water. Bring to a boil. Reduce heat to a simmer and cook until vegetables are extremely tender (read: they\'ve released all their flavor). [...] The great thing about vegetable stock is it starts with a base of carrots, celery, onions and garlic. The other fresh veggies, if you\'re adding more, are negotiable and totally based on what you have on hand. This recipe easily doubles and triples as well. Watch a video of this recipe being prepared during dinner time at my blog: \\n\\n## Ingredients\\n\\n## Directions", "score": 0.9163571, "raw_content": null, "id": "9f40c0-00"}, {"url": "https://www.seriouseats.com/quick-and-easy-vegetable-stock-recipe", "title": "Quick and Easy Vegetable Stock Recipe - Serious Eats", "content": "## Directions\\n\\n1.   Fill a large pot with 4 quarts of water and add carrots, celery, onion, garlic, and herbs. Bring to a low boil over high heat, then reduce to a simmer and let cook for at least 20 minutes and up to 40 minutes. Strain and use as needed.\\n\\n \\n\\n## Special Equipment\\n\\nLarge pot\\n\\n## Notes [...] With a quick trick like this up your sleeve, you\'ll always have time to walk away, no need to run.\\n\\n### November 2015\\n\\nCook Time:\\n\\n20 mins\\n\\nTotal Time:\\n\\n20 mins\\n\\nServings:\\n\\n16 servings\\n\\nYield:\\n\\nMakes about 4 quarts\\n\\nJump to Nutrition Facts\\n\\n Keep Screen Awake \\n\\n## Ingredients\\n\\n   4 medium carrots, peeled and roughly diced\\n\\n   4 stalks celery, roughly diced\\n\\n   2 large onions, roughly diced\\n\\n   4 medium cloves garlic, smashed\\n\\n   Sprigs of fresh parsley, thyme, and/or a dried bay leaf [...] All you need are some aromatic vegetables and water. At the very least, you\'ll want to use carrots, onions, and garlic. Celery helps, as do fresh herbs, like parsley and thyme, and dried ones, like a bay leaf. Anything else that doesn\'t have too particular of a flavor can go in, too. Got fennel bulb on hand, or leeks? Use them. I know some folks like to throw any and all vegetable scraps into their stocks, but I tend to steer clear of certain kinds—like sulfurous brassicas (broccoli, cabbage,", "score": 0.8684817, "raw_content": null, "id": "f9cf93-01"}, {"url": "https://www.loveandlemons.com/how-to-make-vegetable-stock", "title": "How to Make Vegetable Stock Recipe - Love and Lemons", "content": "### Instructions\\n\\n Place the onions, carrots, celery, leek tops, garlic, parsley, thyme, bay leaves, salt, pepper, and water in a large pot and bring to a boil over high heat (If 12 cups of water won’t fit in your pot, you can use 10). Reduce the heat and simmer gently, covered, for 1 hour.\\n Strain and discard the vegetables. Season to taste and use in your favorite soup recipes.\\n\\n### Notes [...] Leeks, onions, bay leaves, celery, carrots, garlic, parsley, and thyme\\n\\n## Vegetable Stock Recipe Ingredients\\n\\nI have two methods for how to make vegetable broth. The first starts with fresh, aromatic veggies. I use\\n\\n onions,\\n garlic,\\n carrots,\\n celery,\\n and herbs like thyme and parsley.\\n\\nThen, to give the broth even more depth of flavor, I add salt, whole peppercorns, leek tops, and bay leaves.\\n\\nVegetable scraps on a cutting board with knife [...] ### Ingredients\\n\\n 2 medium onions, halved\\n 4 medium carrots, chopped\\n 1 to 2 medium celery stalks, chopped\\n Leek or fennel tops, c ...
#               ToolMessage(content='{"query": "mirepoix ingredients carrot celery recipe", "follow_up_questions": null, "answer": null, "images": [], "results": [{"url": "https://feelgoodfoodie.net/recipe/how-to-make-mirepoix", "title": "Mirepoix Recipe {Carrots, Onion & Celery Mix}", "content": "Heat the olive oil in a medium or large skillet or pot, over medium heat. Add the onions, celery and carrots, and stir to coat with the olive oil. Cook, stirring frequently, until the vegetables have softened and the onions are translucent, about 10 minutes.\\n Continue with the recipe as desired, or allow the mirepoix to cool completely and freeze flat in freezer-safe zip top bags. [...] Skip to content\\n\\nFeel Good Foodie\\n\\nRecipes » Tutorials\\n\\n# Mirepoix Recipe\\n\\n: Best for Stocks, Braises and Broths\\n Use Medium-Sized Chunks (about 1/2-inch): Best for Soups and Stews\\n Use Small Chunks (about 1/4-inch): Best for Quick-Cooking Dishes: Risotto, Pan-Sauces and Sautés\\n\\nChunks before cooking. \\n\\nStep 1: Choose what size chunks you want to use based on what you are making. Add the celery, carrots, and onions to a preheated pan with olive oil.\\n\\nAfter cooking. [...] ### Ingredients\\n\\n 1 large onion\\n 3 celery sticks\\n 3 carrot sticks\\n 1 tablespoon olive oil\\n\\n### Instructions", "score": 0.9145431, "raw_content": null, "id": "59a768-00"}, {"url": "https://www.area2farms.com/almanac/mirepoix", "title": "Mirepoix: The Perfect Trio — Area 2 Farms", "content": "To make mirepoix, celery, carrots and onions are diced into small cubes and slowly cooked until golden in healthy fat, like butter or oil, over low to medium heat. This combination of aromatic vegetables is slowly cooked to sweeten and deepen the flavors of various dishes. The traditional ratio for French mirepoix is 1:2:1, with one part celery, two parts onions, and one part carrots.\\n\\nTip: You can store mirepoix in the refrigerator or freezer and use it in future dishes. [...] Mirepoix grasse (meat-based): Combine onions, carrots and celery. And experiment with shallots, thyme, bay leaf, parsley, peppercorns and cloves. Cook in diced bacon or ham with all the fat.\\n\\nMirepoix maigre (Vegetarian) Combine onions, carrots and celery. You can add turnips, shallots, parsley, thyme, bay leaf and peppercorns, and cook everything in butter. [...] Mirepoix (Pronounced Meer-Pwah) is a traditional French combination that serves as a base to build flavor in a number of recipes including stalks, soups and sauces. We grow the three essential ingredients - celery, carrot and onion - used in mirepoix at our organic farm in Arlington, VA, and harvest and deliver them together so that our local community has everything they need to create the foundation for many dishes.\\n\\nLet’s delve into the crops used in mirepoix:", "score": 0.88799405, "raw_content": null, "id": "b37d9a-01"}, {"url": "https://www.seriouseats.com/all-about-mirepoix", "title": "All About Mirepoix, Sofrito, Battuto, and Other Humble Beginnings", "content": "Ingredients for mirepoix; diced carrots, celery, and onions on a cutting board. :max_bytes(150000):strip_icc():format(webp)/__opt__aboutcom__coeus__resources__content_migration__serious_eats__seriouseats.com__2014__05__20190921-mirepoix-vicky-wasik-a2cf6b51641345488de6949a5a71553c.jpg) [...] Ingredients for mirepoix; diced carrots, celery, and onions on a cutting board. :max_bytes(150000):strip_icc():format(webp)/__opt__aboutcom__coeus__resources__content_migration__serious_eats__seriouseats.com__2014__05__20190921-mirepoix-vicky-wasik-a2cf6b51641345488de6949a5a71553c.jpg) [...] Italian Battuto—as the Italian flavor base is called before it is cooked and becomes a soffritto—is kissing cousins to France\'s mirepoix. It starts with the same foundation of onions, carrots, and celery. Parsley leaves, garlic, and fennel, or sometimes finely diced cured meats like pancetta or prosciutto scraps can find its way into the mix. Of course, every Italia ...
#               AIMessage(content='Nice—carrots and celery are classics for cheap, flavorful meals. Here are solid recipe ideas you can make with just those (plus a few pantry staples). Tell me which you want full instructions for and I’ll pull a full recipe.\n\n1) Carrot-Celery Soup (vegan-friendly)\n- Why: Lean, comforting, and quick.\n- Rough idea: Sauté onion, carrot, celery in oil; add garlic; add tomatoes or stock; simmer 15–20 minutes; blend until smooth; season with salt, pepper, and a squeeze of lemon.\n- Quick tweaks: add a potato for creaminess, or a splash of coconut milk or dairy if you like.\n\n2) Carrot-Celery Slaw (crunchy side or topping)\n- Why: Great make-ahead side, works with sandwich or bowls.\n- Rough idea: Shred carrots and celery; whisk a simple dressing (olive oil, lemon or vinegar, a touch of mustard or honey, salt, pepper); toss with the veg; optional add apple, walnuts, or yogurt for creaminess.\n- Quick tweaks: add some chopped herbs or a pinch of chili flakes for zing.\n\n3) Simple Vegetable Stock (base for soups, stews, risottos)\n- Why: Stock is incredibly versatile and can be used in many dishes.\n- Rough idea: Sauté chopped carrot, celery, and onion in oil; add water (or water plus a splash of soy/stock), a bay leaf, peppercorns; simmer 20–40 minutes; strain.\n- Quick tweaks: freeze in ice-cube trays for easy future use; add garlic or herbs if you have them.\n\n4) Mirepoix-based Base for Soups or Braises\n- Why: A flavor-building starter used in many dishes.\n- Rough idea: Dice carrot, celery, and onion; gently cook in oil or butter until soft and slightly golden; use as the flavor base for any soup, stew, or sauce (you can then add other ingredients you have).\n- Quick tweaks: keep it simple or brown it for deeper flavor.\n\nIf you’d like, I can pull full, step-by-step recipes for any of these (or tailor one to what else you have on hand, like onions, garlic, tomatoes, stock, lemon, herbs, or dairy). Which option would you like to start with?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 1707, 'prompt_tokens': 5465, 'total_tokens': 7172, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 1216, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-EHBGgjUlaZIWNjspMViGTrq5oGsqT', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--01a03f03-a435-7603-af08-7cd1209e5311-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 5465, 'output_tokens': 1707, 'total_tokens': 7172, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 1216}})]}
