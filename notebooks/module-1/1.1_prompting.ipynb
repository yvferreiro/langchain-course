# %% [markdown]
# ## Basic prompting

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain.agents import create_agent
from langchain.messages import HumanMessage

agent = create_agent(model="gpt-5-nano")

question = HumanMessage(content="What's the capital of the moon?")

response = agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# There isn’t one. The Moon isn’t a country and has no government or capital. It’s a natural satellite of Earth. (Under the Outer Space Treaty, no nation can claim sovereignty there.) If you’re after a joke, I guess the “capital” would be something like “Luna City” in sci‑fi, not real-life facts. Want some fun lunar trivia instead?

# %%
system_prompt = "You are a science fiction writer, create a capital city at the users request."

scifi_agent = create_agent(
    model="gpt-5-nano",
    system_prompt=system_prompt
)

response = scifi_agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# In this sci‑fi setting, the Moon is a sovereign polity and its capital is:
#
# Lunopolis
#
# Location: perched along the rim of Tycho Crater on the Moon’s near side, a natural amphitheater that gives Lunopolis a commanding view of Earth and the lunar plains beyond.
#
# What Lunopolis is like:
# - Government: The Lunar Confederation, a constitutional republic/polity with a Parliament seated in the Great Dome. The Prime Minister chairs the Council of Craters, the executive body that governs from Lunopolis.
# - Central features:
#   - The Great Dome: the core seat of power, a transparent, radius-6‑story structure where lawmakers debate while Earth rises over the horizon.
#   - The Archive of Echoes: a subterranean network storing holographic memories and data from lunar settlements across the moonscape.
#   - Lumen Gardens: vast hydroponic farms and parks under artificial skylight, providing food and a place for citizens to gather.
#   - The Skyport District: vertical transit towers and a space elevator spur that keeps Lunopolis tightly connected to orbital hubs.
#   - The Crescent Market: a lively, multi-species bazaar in a gravity-diminished zone where traders barter lunar resources, Martian metals, and Earth tech.
# - Culture: a mosaic of Earth diaspora communities and lunar-born settlers. Multilingual streets feel like a fusion of Earth norms and lunar pragmatism; art and science mingle in every plaza.
# - Aesthetic: white basalt towers, glass domes, and solar arrays lace the rim. The city’s glow comes from bioluminescent flora, aurora lighting, and the gentle hum of mag-lev transit.
# - Symbol and motto: a crescent cradling a star, with a motto that translates roughly to “Light without Leaving Home.”
#
# If you’d like, I can tailor Lunopolis further (tone, era, political tilt, or a vibe like hard sci‑fi, dystopian, utopian, or mythic). Would you prefer a far-side capital name or a different lunar polity? Or should I write a quick scene set in Lunopolis?

# %% [markdown]
# ## Few-shot examples

# %%
system_prompt = """

You are a science fiction writer, create a space capital city at the users request.

User: What is the capital of mars?
Scifi Writer: Marsialis

User: What is the capital of Venus?
Scifi Writer: Venusovia

"""

scifi_agent = create_agent(
    model="gpt-5-nano",
    system_prompt=system_prompt
)

response = scifi_agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)

# %% [markdown]
# ## Structured prompts

# %%
system_prompt = """

You are a science fiction writer, create a space capital city at the users request.

Please keep to the below structure.

Name: The name of the capital city

Location: Where it is based

Vibe: 2-3 words to describe its vibe

Economy: Main industries

"""

scifi_agent = create_agent(
    model="gpt-5-nano",
    system_prompt=system_prompt
)

response = scifi_agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)

# %% [markdown]
# ## Structured output

# %%
from langchain.agents import create_agent
from langchain.messages import HumanMessage
from pydantic import BaseModel

class CapitalInfo(BaseModel):
    name: str
    location: str
    vibe: str
    economy: str

agent = create_agent(
    model='gpt-5-nano',
    system_prompt="You are a science fiction writer, create a capital city at the users request.",
    response_format=CapitalInfo
)

question = HumanMessage(content="What is the capital of The Moon?")

response = agent.invoke(
    {"messages": [question]}
)

response["structured_response"]

# %%
response["structured_response"].name

# %%
capital_info = response["structured_response"]

capital_name = capital_info.name
capital_location = capital_info.location

print(f"{capital_name} is a city located at {capital_location}")
