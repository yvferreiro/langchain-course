# %% [markdown]
# ## Text input

# %% [markdown]
# https://platform.openai.com/docs/models

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain.agents import create_agent

agent = create_agent(
    model='gpt-5-nano',
    system_prompt="You are a science fiction writer, create a capital city at the users request.",
)

# %%
from langchain.messages import HumanMessage

question = HumanMessage(content=[
    {"type": "text", "text": "What is the capital of The Moon?"}
])

response = agent.invoke(
    {"messages": [question]}
)

print(response['messages'][-1].content)
# Out:
# In this fictional setting, the capital of The Moon is Selenopolis.
#
# - Location: A raised basalt plateau in the Mare Imbrium on the Moon’s near side, chosen for its clear sightlines to Earth and abundant solar exposure. The city gazes outward toward Earthrise, with a network of glass-domed districts connected by gravity-towered transit.
#
# - Government: The Lunar Commonwealth’s seat of power. The Council of Lunar Wardens and the Office of the First Governor meet in the central Citadel, while the broader administration runs from Selenopolis’ ringed districts.
#
# - Cityscape: A vertical, sunlit city built around gravity towers and crystalline corridors. Outer rings are low-gravity parks and promenades; the core has gravity-bearing districts, markets, and government halls. Much of the life happens in translucent domes that shield residents from micrometeoroids and radiation.
#
# - Landmarks and culture:
#   - The Helium Gate, a massive energy hub and solar-collection lattice.
#   - The Observatory Spire, home to lunar- and Earth-based telescopes.
#   - The Ice Market, trade in water-ice blocks mined from shadowed craters.
#   - The Garden of Echoes, a public plaza where holographic histories of the Moon are performed.
#
# - Economy and resources: Focused on water-ice extraction and processing, Helium-3 mining, and high-density solar energy. The city is designed to recycle air and water efficiently, with subterranean vaults for stability.
#
# If you’d like, I can tailor Selenopolis to a particular era, culture, or technological level (e.g., steampunk lunar city, ultra-modern arcology, or a colony-era frontier capital).

# %% [markdown]
# ## Image input

# %%
from ipywidgets import FileUpload
from IPython.display import display

uploader = FileUpload(accept='.png', multiple=False)
display(uploader)
# Out:
# FileUpload(value=(), accept='.png', description='Upload')

# %%
print(uploader.value)
# Out:
# ({'name': 'moon.png', 'type': 'image/png', 'size': 358916, 'content': <memory at 0x10a952800>, 'last_modified': datetime.datetime(2026, 5, 17, 15, 20, 1, 992000, tzinfo=datetime.timezone.utc)},)

# %%
import base64

# Get the first (and only) uploaded file dict
uploaded_file = uploader.value[0]

# This is a memoryview
content_mv = uploaded_file["content"]

# Convert memoryview -> bytes
img_bytes = bytes(content_mv)  # or content_mv.tobytes()

# Now base64 encode
img_b64 = base64.b64encode(img_bytes).decode("utf-8")

# %%
multimodal_question = HumanMessage(content=[
    {"type": "text", "text": "Tell me about this capital"},
    {"type": "image", "base64": img_b64, "mime_type": "image/png"}
])

response = agent.invoke(
    {"messages": [multimodal_question]}
)

print(response['messages'][-1].content)
# Out:
# Here’s a complete portrait of the capital you’re looking at. I’ll name it Crownspire, the seat of governance and culture for the frontier world Cael IX.
#
# Inspiration from the image
# - Crownspire sits in a rugged canyon basin, cliffs carved by wind and ancient tectonics.
# - A vast blue planet fills the sky, lending a pale, otherworldly light to the city’s glassy surfaces.
# - The skyline is dominated by towering, slender spires and crystalline structures that seem to catch every photon and bend it into color.
#
# The city at a glance
# - Name: Crownspire
# - Location: Capital city of the planet Cael IX, perched at the rim of a colossal canyon above Lumin Lake, with a network of bridges and skyways connecting the cliff faces.
# - Ambience: A fusion of ancient rock-carving and ultramodern architecture; the feel is ceremonial yet intensely practical, with energy and data humming in the air.
#
# Layout and districts
# - The Crown District (central seat of power): A concentric core of government buildings, the Harmonic Forum, and the Opus Archives. The centerpiece is a colossal crown-shaped plaza where civic ceremonies happen at dawn.
# - Spine Ward: A vertical ribbon of mixed-use towers that rise along a fault line; homes, studios, and offices are stacked in terraces that cascade down toward the lake.
# - Lumin Basin: The outer ring of markets, workshops, and residential harbors; stalls glow with bioluminescent fabrics and mineral dyes harvested nearby.
# - Garden Quintessence: A system of terraced sky-gardens and greenhouse domes that float above the canyon floor, cooled by purified canyon winds.
# - Echo Walk: A pedestrian canyon promenade lined with acoustic sculptures; the soundscape changes with the weather and solar angle.
#
# Architecture and materials
# - Towers and domes: Built from a composite of basalt-like rock, tempered glass, and a lattice of light-responsive alloys. The surfaces shimmer with a soft, turquoise-blue sheen when illuminated by Cael IX’s twin suns and the distant blue planet.
# - Facades: Layered, with open-air terraces, cantilevered ports, and glass that doubles as solar sails during storms.
# - Public spaces: Amphitheaters carved into cliff faces and crystalline plazas that bend sound, making declarations carry like a choir’s note across the city.
# - Infrastructure: A grid of gravity-lev railways, aerial tramways, and sky-borne elevators that spool between towers and canyon ledges.
#
# Governance and society
# - Political structure: Crownspire sits at the heart of a federated republic known as the Caelian Concord. The city hosts the Harmonic Senate, a technocratic-ceremonial body that also includes representatives of guilds, scientists, and cultural stewards.
# - The Crown: A symbolic title held by a rotating council of architects, engineers, and poets who interpret the will of the people through design and ritual. The Crown’s “functions” are to approve megaprojects, oversee treaties, and maintain the city’s cultural memory.
# - Social fabric: A meritocratic meritocracy with an emphasis on craftsmanship, scholarship, and service. Public life values transparency, community ritual, and the protection of Cael IX’s fragile water and mineral resources.
# - Security: A civic guard known as the Echo Ward uses non-lethal tech, sonic boundary enforcement, and gravitik (gravitational) restraints to keep order while preserving civil liberties.
#
# Culture, life, and arts
# - Everyday life: Markets rise at dusk; artisans trade luminous textiles, crystalss, and alloy-core hardware. Civic rituals—music, light shows, and synchronized drone ballets—mark changing seasons and celestial events.
# - Arts: A thriving culture of instrument-making and sound architecture. Buildings double as instruments; plazas host resonant performances where architecture “plays” the notes.
# - Festivals: The Night of Lumin—when Lumin Lake’s bioluminescent flora blooms and the city’s towers reflect the lights of Cael IX’s moons. The Crown Festival celebrates the founding of Crownspire with pageants, processions, and a city-wide chorus performed from every balcony.
# - Garb and language: Residents wear light-absorbing textiles with adaptive color patches that glow during ceremonies. The common language is Caelian, with local dialects mixing in markets and academy halls.
#
# Technology and economy
# - Energy: Solar harvesters and a renewable “aqua-crystal” grid that channels subterranean mineral-water conduits. Energy is abundant, but resources are carefully managed to avoid waste.
# - Industry: Advanced materials, optics, and terraforming-adjacent tech. Crownspire hosts laboratories for asteroid-mining optimization, climate stabilization, and water-scarce agriculture.
# - Trade: A hub for interplanetary trade, especially rare minerals, crafts, and data services. The Azure Gate portal-like structure (more myth than machine) is a ceremonial relic that now serves as a ceremonial docking site for data couriers and diplomats.
# - Transportation tech: Personal grav-cabs, tethered air-trams, and subterranean hyper-tunnels that link Crownspire to other settlements on Cael IX.
#
# Landmarks and sights
# - The Prism of Nine Suns: A cathedral-like structure at the Crown District where light is split into visible and invisible spectra for ceremonies and scientific demonstrations.
# - The Azure Gate: A monumental arch at the canyon rim that aligns with the blue planet during celestial alignments; it’s both a monument and a working data vault of star charts.
# - The Lumen Lake Dunes: A shimmering blue lake with floating islets and reflective sands that hold ceremonial camps during the Night of Lumin.
# - The Echo Choir: An open-air amphitheater carved into a cliff face that doubles as a concert hall where sound flows through the rock and responds to the audience.
#
# History and legends
# - Founding: Crownspire grew from a rock-cut outpost that guarded an ancient trade route; it became the planetary capital after a century of civil union among mining clans and agrarian settlements.
# - Trials: The city survived a century-long drought sparked by a solar storm by building the Lumin Basin’s climate domes and pioneering water purification towers.
# - Mythic relics: The Azure Gate is believed to be a gateway not just of space but of memory—a place where visitors feel the city’s long history echo back through time.
#
# What life feels like in Crownspire
# - The air around the towers carries a soft hum of machinery and music. People move with a practiced ease between public ceremonies and daily logistics—markets under crystal awnings, neighbors swapping stories atop terraced gardens, scientists greeting tourists at a lakefront plaza.
# - The nights are cool and blue-lit; the city glows softly from within the glass and mineral features, while the planet’s giant orb lingers above the skyline like a benevolent overseer.
#
# Story hooks and ideas for you
# - A political storm: A dispute over resource allocation tests the Concord’s balance between ceremony and practical governance. Crownspire’s rotating Crown council must reconcile tradition with a sudden economic shift.
# - A science mystery: A peculiar resonance is detected from the Azure Gate; researchers suspect it’s not merely a relic but a communication device—or a trap.
# - A cultural mystery: A performer from the Garden Quintessence discovers a hidden archive within the canyon walls that could rewrite Cael IX’s history.
#
# If you’d like, I can tailor Crownspire to a different climate, age, or backstory—more ancient and ritualistic, or more high-tech and dystopian. Want me to rename it, switch planets, or shift the vibe (gritty frontier, utopian beacon, or noir-capital)?

# %% [markdown]
# ## Audio input

# %%
import sounddevice as sd
from scipy.io.wavfile import write
import base64
import io
import time
from tqdm import tqdm

# Recording settings
duration = 5  # seconds
sample_rate = 44100

print("Recording...")
audio = sd.rec(int(duration * sample_rate), samplerate=sample_rate, channels=1)
# Progress bar for the duration
for _ in tqdm(range(duration * 10)):   # update 10× per second
    time.sleep(0.1)
sd.wait()
print("Done.")

# Write WAV to an in-memory buffer
buf = io.BytesIO()
write(buf, sample_rate, audio)
wav_bytes = buf.getvalue()

aud_b64 = base64.b64encode(wav_bytes).decode("utf-8")
# Out:
# Recording...
# 100%|██████████| 50/50 [00:05<00:00,  9.53it/s]
# Done.

# %%
agent = create_agent(
    model='gpt-audio',
)

multimodal_question = HumanMessage(content=[
    {"type": "text", "text": "Tell me about this audio file"},
    {"type": "audio", "base64": aud_b64, "mime_type": "audio/wav"}
])

response = agent.invoke(
    {"messages": [multimodal_question]}
)

print(response['messages'][-1].content)
# Out:
# It sounds like the audio file contains someone repeatedly saying the phrase "one two three" in sequence. If you have any specific questions or need analysis related to the content, feel free to ask. I’m here to help.
