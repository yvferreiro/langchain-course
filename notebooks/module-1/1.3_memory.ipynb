# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %% [markdown]
# ## No memory

# %%
from langchain.agents import create_agent


agent = create_agent(
    "gpt-5-nano"
)

# %%
from langchain.messages import HumanMessage

question = HumanMessage(content="Hello my name is Yolanda and my favourite colour is blue")

response = agent.invoke(
    {"messages": [question]} 
)

# %%
from pprint import pprint

pprint(response)
# Out:
# {'messages': [HumanMessage(content='Hello my name is Yolanda and my favourite colour is blue', additional_kwargs={}, response_metadata={}, id='8c001989-6572-4e61-9fe8-a22462e935d4'),
#               AIMessage(content='Nice to meet you, Yolanda! Blue is a fantastic color—calming and versatile. How can I help today? I can help with blue-themed ideas (color palettes, outfits, decor), share fun facts about blue, or just chat. What would you like to do?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 578, 'prompt_tokens': 18, 'total_tokens': 596, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 512, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-EHAzOnkBWGzwD4hTTLli5b4Opsiih', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--01a03ef3-4734-7ce0-9c2d-1a3c912d4f5b-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 18, 'output_tokens': 578, 'total_tokens': 596, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 512}})]}

# %%
question = HumanMessage(content="What's my favourite colour?")

response = agent.invoke(
    {"messages": [question]} 
)

pprint(response)
# Out:
# {'messages': [HumanMessage(content="What's my favourite colour?", additional_kwargs={}, response_metadata={}, id='b4a0cba5-63b3-41a3-83a1-6e7ade0a388a'),
#               AIMessage(content='I don’t know your favourite color yet. Want me to figure it out with a quick guess game, or would you rather tell me a color you like?\n\nIf you want to play a quick guess game, answer these 3 quick questions:\n1) Do you prefer cool colors (blue/green/purple) or warm colors (red/orange/yellow)?\n2) Do you like bright/saturated colors or softer/muted tones?\n3) Do you want the color to feel calming, energizing, or luxurious?\n\nTell me your answers (or just pick one option for each), and I’ll suggest your likely favourite. If you’d rather skip, you can just tell me a color you like and I’ll help confirm it.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 2141, 'prompt_tokens': 11, 'total_tokens': 2152, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 1984, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-EHAzhldmK9dgc5BU0bG4f2oROwGzO', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--01a03ef3-8fec-7770-8de6-db744071e449-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 11, 'output_tokens': 2141, 'total_tokens': 2152, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 1984}})]}

# %% [markdown]
# ## Memory

# %%
from langgraph.checkpoint.memory import InMemorySaver  


agent = create_agent(
    "gpt-5-nano",
    checkpointer=InMemorySaver(),  
)

# %%
from langchain.messages import HumanMessage

question = HumanMessage(content="Hello my name is Yolanda and my favourite colour is blue")
config = {"configurable": {"thread_id": "1"}}

response = agent.invoke(
    {"messages": [question]},
    config,  
)

# %%
pprint(response)
# Out:
# {'messages': [HumanMessage(content='Hello my name is Seán and my favourite colour is green', additional_kwargs={}, response_metadata={}, id='1b8d0165-0cb6-40c5-af2e-d6315b162b02'),
#               HumanMessage(content='Hello my name is Yolanda and my favourite colour is blue', additional_kwargs={}, response_metadata={}, id='53ae7b13-2171-4381-9c06-3b02a413e4f7'),
#               AIMessage(content='Nice to meet you both!\n\n- Seán: green is a fantastic choice—calming and vibrant.\n- Yolanda: blue is lovely—versatile and soothing.\n\nWhat would you like me to do with these preferences? Here are a few ideas:\n- Write a short story or scene featuring Seán’s green and Yolanda’s blue\n- Create color-inspired palettes or mood boards\n- Generate quick facts or a tiny profile for each person\n- Set up a simple memory note for this chat about your favorite colors\n\nTell me your preference, or suggest something else!', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 700, 'prompt_tokens': 34, 'total_tokens': 734, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 576, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-EHB0OhOZEY1OPNfk1ET47GZLXJKzy', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--01a03ef4-39e9-72d0-ab12-25afd631c2a6-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 34, 'output_tokens': 700, 'total_tokens': 734, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 576}})]}

# %%
question = HumanMessage(content="What's my favourite colour?")

response = agent.invoke(
    {"messages": [question]},
    config,  
)

pprint(response)
# Out:
# {'messages': [HumanMessage(content='Hello my name is Seán and my favourite colour is green', additional_kwargs={}, response_metadata={}, id='1b8d0165-0cb6-40c5-af2e-d6315b162b02'),
#               HumanMessage(content='Hello my name is Yolanda and my favourite colour is blue', additional_kwargs={}, response_metadata={}, id='53ae7b13-2171-4381-9c06-3b02a413e4f7'),
#               AIMessage(content='Nice to meet you both!\n\n- Seán: green is a fantastic choice—calming and vibrant.\n- Yolanda: blue is lovely—versatile and soothing.\n\nWhat would you like me to do with these preferences? Here are a few ideas:\n- Write a short story or scene featuring Seán’s green and Yolanda’s blue\n- Create color-inspired palettes or mood boards\n- Generate quick facts or a tiny profile for each person\n- Set up a simple memory note for this chat about your favorite colors\n\nTell me your preference, or suggest something else!', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 700, 'prompt_tokens': 34, 'total_tokens': 734, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 576, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-EHB0OhOZEY1OPNfk1ET47GZLXJKzy', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--01a03ef4-39e9-72d0-ab12-25afd631c2a6-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 34, 'output_tokens': 700, 'total_tokens': 734, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 576}}),
#               HumanMessage(content="What's my favourite colour?", additional_kwargs={}, response_metadata={}, id='6163180e-65b9-4140-b3bf-a5289b00eb86'),
#               AIMessage(content='Do you mean Seán or Yolanda? Based on what you told me earlier:\n\n- If you’re Seán, your favourite colour is green.\n- If you’re Yolanda, your favourite colour is blue.\n\nWhich one should I use, or would you like me to remember a single favorite for this chat? I can also do color-inspired ideas or quick profiles if you’d like.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 855, 'prompt_tokens': 164, 'total_tokens': 1019, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 768, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-EHB0nQFjUvGSYmBeEK6PH2P3qVo7s', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--01a03ef4-99a0-74a3-a6af-9bcbf8a427f3-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 164, 'output_tokens': 855, 'total_tokens': 1019, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 768}})]}
